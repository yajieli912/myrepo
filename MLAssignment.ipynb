# %% [markdown]
# # Assessment Questions

# %% [markdown]
# ## 1. Loading data into Pandas

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('survey.csv')
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees   ...     \
# 0             No       Yes          Often            6-25   ...
# 1             No        No         Rarely  More than 1000   ...
# 2             No        No         Rarely            6-25   ...
# 3            Yes       Yes          Often          26-100   ...
# 4             No        No          Never         100-500   ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %% [markdown]
# ## 2. Writing an apply function that transforms a column

# %% [markdown]
# The function I wrote is to unify the input of Gender column

# %%
def treatment_revise(treatment):
    if treatment == 'Yes':
        return 1
    else:
        return 0
df['treatment'] = df['treatment'].apply(treatment_revise)
df
# Out:
#                 Timestamp  Age  \
# 0     2014-08-27 11:29:31   37
# 1     2014-08-27 11:29:37   44
# 2     2014-08-27 11:29:44   32
# 3     2014-08-27 11:29:46   31
# 4     2014-08-27 11:30:22   31
# 5     2014-08-27 11:31:22   33
# 6     2014-08-27 11:31:50   35
# 7     2014-08-27 11:32:05   39
# 8     2014-08-27 11:32:39   42
# 9     2014-08-27 11:32:43   23
# 10    2014-08-27 11:32:44   31
# 11    2014-08-27 11:32:49   29
# 12    2014-08-27 11:33:23   42
# 13    2014-08-27 11:33:26   36
# 14    2014-08-27 11:33:57   27
# 15    2014-08-27 11:34:00   29
# 16    2014-08-27 11:34:20   23
# 17    2014-08-27 11:34:37   32
# 18    2014-08-27 11:34:53   46
# 19    2014-08-27 11:35:08   36
# 20    2014-08-27 11:35:12   29
# 21    2014-08-27 11:35:24   31
# 22    2014-08-27 11:35:48   46
# 23    2014-08-27 11:36:24   41
# 24    2014-08-27 11:36:48   33
# 25    2014-08-27 11:37:08   35
# 26    2014-08-27 11:37:23   33
# 27    2014-08-27 11:37:59   35
# 28    2014-08-27 11:38:12   34
# ...

# %% [markdown]
# ## 3.  A basic Data Visualization using Seaborn or Plotly library or Matplotlib

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Put #NBVAL_IGNORE_OUTPUT for the below cell since the test run produces different name in "matplotlib.axes._subplots.AxesSubplot at 0x112a677b8"

# %%
#NBVAL_IGNORE_OUTPUT
sns.countplot(x='Age', data=df)

# %% [markdown]
# ## 4.  Some type of Machine Learning technique on the data

# %% [markdown]
# Put #NBVAL_IGNORE_OUTPUT for the below cell since the test run will have a different timestamp, which causes the "disagrees with newly computed (test) output".

# %%
#NBVAL_IGNORE_OUTPUT
import statsmodels.api as sm

X = df["Age"]
y = df["treatment"]
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              treatment   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.978
# Date:                Fri, 29 Dec 2017   Prob (F-statistic):              0.160
# Time:                        10:25:13   Log-Likelihood:                -1356.6
# No. Observations:                1259   AIC:                             2715.
# Df Residuals:                    1258   BIC:                             2720.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age             1e-11   7.11e-12      1.406      0.160   -3.95e-12    2.39e-11
# ...
